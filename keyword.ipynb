# %%
import pandas as pd

import geopandas as gpd


file = pd.read_excel('/home/ronit/Downloads/keyword/Station.xls', sheet_name="14.02.22")
# print(file)
# file.loc[0:]
f = file[['Abnormalities/ Deficiencies found ( In Brief)','Department/Area inspected Such as Loco/Coach/Track/Station etc.']]
f
# list =[]
# for i in f:
#     list.append(f)
# #     print(list[:-1])
    
# k = list[:-1]
# k
# for i in f:
#     print(i)
# cols  = file.columns.to_list()
# col = cols[7]
# print(col)
# print('---------------------------------------------')
# list =[]
data = f['Abnormalities/ Deficiencies found ( In Brief)']
# # print(data)
# list.append(data)
# list
# for i in list:
#     k = i[81]
#     s = k.split(' ')
#     print(s)
#     if 'Broken' in s:
#         print('matched')
#         print(k)
#     else:
# #         print('matched not')

list1 = data.astype(str).str.split(' ')
# list1
lo = []
match = ['broken','cabin']
for matches in match:
#     print(matches)
    print('----------')
    for i,index in enumerate(list1):
        
#         print(i)
        if  matches in index:
            
            x = ' '.join(index)
            print(i,'======>',x)
#             print('----------')
            print('matched')
            print('-----------')
#             f = file[['Abnormalities/ Deficiencies found ( In Brief)','Department/Area inspected Such as Loco/Coach/Track/Station etc.']]
         
            l = file.loc[i]
            fd = l[6]
            lo.append(fd)

            df = pd.DataFrame(data=l)
            df1_transposed = df.T
print(lo)
# file = 'keywprds.txt'
# with open(file,'a') as f:
#     f.write(str(lo))
#     print('=======saved=======')
# for il in lo:
#     print(il)
#             print(df1_transposed)
#             li = []
#             lo.append(df1_transposed)
#             print(li)
#             for ll in li:
#                 print(ll[0:2])
# for kk in lo:

#     df1 = pd.DataFrame(data=kk)
# # df1 = df1.T
#     print (df1)

# for i,index in enumerate(list1):
#     d = i,index
# #     print(d)
#     k = index[81:93]
#     for ik in k:
# #         print(ik)
    
# #         s = ik.split(' ')
#     #     print(s)
#         if 'Broken' in s:
#             print('matched')
#             print(k)
#         else:
#             print('matched not')


# import pandas as pd
  
    
# fo = pd.read_csv('keywprds.txt')
# # fo
# # print(fo)
# list = [""]
# for ff in fo:
# #     print(len(ff))
#     spl = ff.split(" ")
#     spl.pop(0)
#     #print(spl)
#     for sp in spl:
        
#         st= str(sp)
#         re = st.replace("]",' ')
#         rep = re.replace("'"," ")
     
#         list.append(rep)
# print(type(list))
# conset = set(list)
# print(conset)
# for ll in list:
#     print(ll)
# conset = set(lo)
# sc = lo.split(" ")
listofdata= []
for lll in lo:
    sc = lll.split(" ")
    print(sc)
#     print(conset)
    gf = gpd.read_file('/home/ronit/Downloads/keyword/IR STATION MASTER MEITY.shp')
    d =gf.columns[4]
    data = gf[d]

    # dl = []
    # dl.append(data)
    # print(dl)

    list1 = data.astype(str).str.split(' ')
    # print(list1)
    for con in sc:
#         print(con)

    # # data
        for dx,cons in enumerate (list1):
    #         print(dx,cons)
    #     for dm,i in e/numerate(data,0):
    #         print(i)
            if con in cons:
#                 print('matched-----------------------------------------------------yyyyyyyyyyyyyyyyy')
                y = ' '.join(cons)
#                 print(y)
               
                lc = gf.loc[dx]
#                 cols = lc[8]
#                 print(lc,'==========================================')
                listofdata.append(lc)
# print(listofdata)
dataframes = pd.DataFrame(data=listofdata)
print(dataframes)
print('-----------')

print("Searching finished")
# Out:
# ----------
# 4 ======> (1)South side side FOB found dirty with broken glass (2)Elementary section 82910 on Dn line does not exist with TPC/ATNL diagram where E/S 83109on up line does not exist in station diagram.
# matched
# -----------
# 8 ======> platform number 1 old water tank very damage condition and surat in FOB no cover set provided so rainy season public complaint in future. platform number 1 KFF STATION end safety wall very damage condition. platform number 1 Near toilet room platform plate broken and dug. navapur railway station railway colony e traffic department it quarters are are very old and damage condition. new railway quarters building no provided traffic staff any quarters
# matched
# -----------
# 29 ======> Coach no. 094010GS and 142404CN dashpot cover broken and axle box canted in both coaches, detached sick
# matched
# -----------
# 114 ======> (1) Railway quarter(Tfc) need to be major repaired. (2) At LC/24,the door and sheet of toilet are in broken condition. (3) At LC/23, working gate lodge nees to be major repaired, (4) Tin sheet provided on floor at working gate lodge of LC/23,is broken needs to be replaced. (5) Off side P/man's gumtee needs to be provided.
# matched
# -----------
# 237 ======> (1)Pt.124 Crossing rubber pads crushed. (2)Pt.130 GFN liners broken 20 nos. (3)02 Bolts loose in crossing 205.
# matched
# -----------
# 251 ======> 1. The withered tree needs to be removed from the platform no 1 which may fall at any time.  2. Fancing of PF-1&2 broken from many places and provide way for trespassing.
# matched
# -----------
# 257 ======> RTM-NAD sec. FP by 15046 Dn.
# LOCO no-37258 WAP7 TKD
# 1. LOCO cab-1 Gauge lights not working.
# 2.Both Cab CBC Operating Handle broken Condition.
# 3.Loco HOG-1 Convertor not working. (Remark for  Home shed TKD).
# matched
# -----------
# ----------
# 9 ======> one Portable cabin lying idle at the north side of PF No 3 at KM 26/15-16
# matched
# -----------
# ['AN', 'Night foot plate', 'Inspection of 19007 train in Washing line ST', 'UMH station, LC/23, LC/24', 'SMP Yd. P&C Inspection', 'RAU', 'Foot plate ', 'GMN']
# ['AN']
# ['Night', 'foot', 'plate']
# ['Inspection', 'of', '19007', 'train', 'in', 'Washing', 'line', 'ST']
# ['UMH', 'station,', 'LC/23,', 'LC/24']
# ['SMP', 'Yd.', 'P&C', 'Inspection']
# ['RAU']
# ['Foot', 'plate', '']
# ['GMN']
#       ZONE CODE        ZONE FULL DIVISION C      DIVISION N STATION CO  \
# 11904        WR  WESTERN RAILWAY        BCT  MUMBAI CENTRAL         AN
# 11129        WR  WESTERN RAILWAY        BCT  MUMBAI CENTRAL         ST
# 11222        WR  WESTERN RAILWAY        BRC        VADODARA        UMH
# 11836        WR  WESTERN RAILWAY        RTM          RATLAM        SMP
# 11860        WR  WESTERN RAILWAY        RTM          RATLAM        RAU
# 11071        WR  WESTERN RAILWAY        BCT  MUMBAI CENTRAL        GMN
#
#         STATION FU  PIN CODE   LOGITUDE   LATITUDE           STATE  \
# 11904      AMALNER  425401.0  75.057262  21.049526     MAHARASHTRA
# 11129        SURAT  395003.0  72.840975  21.205996         GUJARAT
# 11222       UMRETH  388220.0  73.119635  22.693023         GUJARAT
# 11836  SHAMBHUPURA  312204.0  74.642117  24.770823       RAJASTHAN
# 11860          RAU  453331.0  75.805105  22.633516  MADHYA PRADESH
# 11071     GOREGAON  400063.0  72.849499  19.165201     MAHARASHTRA
#
#                               geometry
# 11904      POINT (75.057262 21.049526)
# 11129      POINT (72.840975 21.205996)
# 11222      POINT (73.119635 22.693023)
# 11836  POINT (74.64211667 24.77082333)
# 11860  POINT (75.80510533 22.63351617)
# 11071   POINT (72.8494995 19.16520117)
# -----------
# Searching finished

# %%
import pandas as pd

fo = pd.read_csv('keywprds.txt')
# fo
# print(fo)
for ff in fo:
#     print(len(ff))
    spl = ff.split(" ")
    spl.pop(0)
    print(spl)
    
    
    
    
    
    
    
    fo = pd.read_csv('keywprds.txt')
# fo
# print(fo)
list = []
for ff in fo:
#     print(len(ff))
    spl = ff.split(" ")
    spl.pop(0)
    #print(spl)
    for sp in spl:
        
        st= str(sp)
        re = st.replace("]",' ')
        rep = re.replace("'"," ")
        list.append(rep)
# print(list[2])
conset = set(list)
# print(conset)
s = "Nigh"
for en,con in enumerate (conset):
    print(con)
    if s in con:
       
        print(en,'-----------------------matched')
#         for idx,lo in enumerate (list):
#             print(idx[en])
# Out:
# []
# ["'Night", 'foot', "plate'"]
# ["'Inspection", 'of', '19007', 'train', 'in', 'Washing', 'line', "ST'"]
# ["'UMH", 'station']
# ['LC/23']
# ["LC/24'"]
# ["'SMP", 'Yd.', 'P&C', "Inspection'"]
# ["'RAU'"]
# ["'Foot", 'plate', "']"]
#  Foot
# of
#  SMP
# plate
#
#  RAU
#  Night
# 6 -----------------------matched
# in
# 19007
# Inspection
# plate
# ST
# P&C
# Yd.
# station
# train
#  Inspection
# line
# Washing
#  UMH
# foot
# LC/24
# LC/23

# %%
import geopandas as gpd
# import pandas as pd
  
    
# fo = pd.read_csv('keywprds.txt')
# # fo
# # print(fo)
# list = [""]
# for ff in fo:
# #     print(len(ff))
#     spl = ff.split(" ")
#     spl.pop(0)
#     #print(spl)
#     for sp in spl:
        
#         st= str(sp)
#         re = st.replace("]",' ')
#         rep = re.replace("'"," ")
     
#         list.append(rep)
print(type(list))
# conset = set(list)
# print(conset)
# for ll in list:
#     print(ll)
gf = gpd.read_file('/home/ronit/Downloads/keyword/IR STATION MASTER MEITY.shp')
d =gf.columns[4]
data = gf[d]
# dl = []
# dl.append(data)
# print(dl)

list1 = data.astype(str).str.split(' ')
# print(list1)
for con in list:
    print(con)
    
# data
    for dx,cons in enumerate (list1):
#         print(dx,cons)
#     for dm,i in e/numerate(data,0):
#         print(i)
        if con in cons:
            print('matched---------------')
print('-----------')
# Out:
# <class 'list'>
#
#  Night
# foot
# plate
#  Inspection
# of
# 19007
# train
# in
# Washing
# line
# ST
#  UMH
# station
# LC/23
# LC/24
#  SMP
# Yd.
# P&C
# Inspection
#  RAU
#  Foot
# plate
#
# -----------
